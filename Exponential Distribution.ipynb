# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
x=np.array([1,2,3,4,5,6])
mean=np.mean(x)
p=np.empty(6)
for i in range(0,6):
    fun=(mean)*(math.e**(x[i]*(-mean)))
    p[i]=fun
#following codes plots the points and joins them using a smooth quadratic curve
x_new = np.linspace(x.min(), x.max(),500)
f = interp1d(x, p, kind='quadratic')
y_smooth=f(x_new)
plt.plot (x_new,y_smooth,linewidth=3)
plt.scatter(x,p,color='crimson',s=60,)
plt.xlabel('X')
plt.ylabel('P(X)')
plt.title('Exponential distribution')
plt.grid()
plt.show();

# %%
#following codes plots the points and joins them using a smooth quadratic curve
x_new = np.linspace(x.min(), x.max(),500)
f = interp1d(x, p, kind='quadratic')
y_smooth=f(x_new)
plt.plot (x_new,y_smooth,linewidth=5)
