# %%
import numpy as np
import math
import matplotlib.pyplot as plt
x=(np.random.random([6])*6)-3
p=np.full([6],1/6)
plt.plot(x,p,'go-',linewidth=0.6)
plt.xlabel('X')
plt.ylabel('P(X)')
plt.title('Uniform Distribution')
plt.grid()
plt.show();
